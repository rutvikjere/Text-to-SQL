# %% [markdown]
# ### Libraries and API Keys:

# %%
# Importing the necessary libraries:
import os
import pandas as pd
import numpy as np
import transformers
import langchain
import pymysql
import tiktoken
from langchain.text_splitter import TokenTextSplitter
from langchain import HuggingFaceHub, SQLDatabase, PromptTemplate, FewShotPromptTemplate
from langchain.chains import SQLDatabaseChain
from langchain.document_loaders.csv_loader import CSVLoader
from langchain.vectorstores import FAISS
from langchain.embeddings import HuggingFaceEmbeddings
from transformers import RagModel, RagTokenizer, RagRetriever

# Setting the environment for the Hugging face API:
os.environ["HUGGINGFACEHUB_API_TOKEN"] = "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"

# %% [markdown]
# ### Flan-T5-xxl is the only reliable model:

# %%
# Prompt Attempt:
model = "google/flan-t5-xxl" #'Sandiago21/llama-7b-hf-prompt-answering'

llm = HuggingFaceHub(repo_id=model, model_kwargs={"temperature":0.5, "max_length":512})

prompt = "Alice has a parrot. What animal is Alice's pet?"
print(llm(prompt))
# Out:
# parrot

# %% [markdown]
# ### Creating an LLM SQL chain with the winestore database

# %% [markdown]
# #### Intention is the to query the SQL DB with the LLM's response.

# %%
# Be sure to add the password to the db and the name of the schema
sql_uri = "mysql+pymysql://root:Liklik69&@localhost:3306/wine_store"

# %%
db = SQLDatabase.from_uri(sql_uri)

# %%
db_chain = SQLDatabaseChain.from_llm(llm, db, verbose=True)

# %% [markdown]
# ### Zero Shot:

# %%
PROMPT = """ 
Given an input question, first create a syntactically correct MySQL query to run,  
then look at the results of the query and return the answer.  
The question: {question}
"""

# %%
question = "what is the average price from the table purchasepricesdec?" 

db_chain.run(PROMPT.format(question=question))
# Out:
# > Entering new  chain...
#
# Given an input question, first create a syntactically correct MySQL query to run,
# then look at the results of the query and return the answer.
# The question: what is the average price from the table purchasepricesdec?
#
# SQLQuery:SELECT avg(Price) FROM purchasepricesdec
# SQLResult: [(38.65188805482593,)]
# Answer:38.65188805482593
# > Finished chain.
# '38.65188805482593'

# %% [markdown]
# ### Few Shot:

# %%
# Few Shot:
examples = [
  {"question": "What is the average of the PurchasePrice in the table purchasepricesdec?",
    "answer": "26.48821956"},
  {"question": "How many unique values do we have in the Classification column in the table purchasepricesdec?",
    "answer": "2"},
  {"question": "How many rows do we have in the table purchasepricesdec?",
    "answer":"12262"},
  {"question": "What is the mode of the Volume column in purchasepricesdec table?",
    "answer":"750"}
]

example_prompt = PromptTemplate(input_variables=["question", "answer"], template="Question: {question}\n{answer}")

prompt = FewShotPromptTemplate(
    examples=examples, 
    example_prompt=example_prompt, 
    suffix="Question: {input}", 
    input_variables=["input"]
)

db_chain.run(prompt.format(input="What is the mean of the Volume column in the purchasepricesdec table?"))
# Out:
# > Entering new  chain...
# Question: What is the average of the PurchasePrice in the table purchasepricesdec?
# 26.48821956
#
# Question: How many unique values do we have in the Classification column in the table purchasepricesdec?
# 2
#
# Question: How many rows do we have in the table purchasepricesdec?
# 12262
#
# Question: What is the mode of the Volume column in purchasepricesdec table?
# 750
#
# Question: What is the mean of the Volume column in the purchasepricesdec table?
# SQLQuery:SELECT avg(T1.PurchasePrice) FROM purchase
# ---------------------------------------------------------------------------
# ProgrammingError                          Traceback (most recent call last)
# File ~\SoftwaresIDES\lib\site-packages\sqlalchemy\engine\base.py:1819, in Connection._execute_context(self, dialect, constructor, statement, parameters, execution_options, *args, **kw)
#    1818     if not evt_handled:
# -> 1819         self.dialect.do_execute(
#    1820             cursor, statement, parameters, context
#    1821         )
#    1823 if self._has_events or self.engine._has_events:
#
# File ~\SoftwaresIDES\lib\site-packages\sqlalchemy\engine\default.py:732, in DefaultDialect.do_execute(self, cursor, statement, parameters, context)
#     731 def do_execute(self, cursor, statement, parameters, context=None):
# --> 732     cursor.execute(statement, parameters)
#
# File ~\SoftwaresIDES\lib\site-packages\pymysql\cursors.py:148, in Cursor.execute(self, query, args)
#     146 query = self.mogrify(query, args)
# --> 148 result = self._query(query)
#     149 self._executed = query
#
# File ~\SoftwaresIDES\lib\site-packages\pymysql\cursors.py:310, in Cursor._query(self, q)
#     309 self._clear_result()
# --> 310 conn.query(q)
#     311 self._do_get_result()
#
# File ~\SoftwaresIDES\lib\site-packages\pymysql\connections.py:548, in Connection.query(self, sql, unbuffered)
#     547 self._execute_command(COMMAND.COM_QUERY, sql)
# --> 548 self._affected_rows = self._read_query_result(unbuffered=unbuffered)
#     549 return self._affected_rows
#
# File ~\SoftwaresIDES\lib\site-packages\pymysql\connections.py:775, in Connection._read_query_result(self, unbuffered)
#     774     result = MySQLResult(self)
# --> 775     result.read()
#     776 self._result = result
#
# File ~\SoftwaresIDES\lib\site-packages\pymysql\connections.py:1156, in MySQLResult.read(self)
#    1155 try:
# -> 1156     first_packet = self.connection._read_packet()
#    1158     if first_packet.is_ok_packet():
#
# File ~\SoftwaresIDES\lib\site-packages\pymysql\connections.py:725, in Connection._read_packet(self, packet_type)
#     724         self._result.unbuffered_active = False
# --> 725     packet.raise_for_error()
#     726 return packet
#
# File ~\SoftwaresIDES\lib\site-packages\pymysql\protocol.py:221, in MysqlPacket.raise_for_error(self)
#     220     print("errno =", errno)
# --> 221 err.raise_mysql_exception(self._data)
#
# File ~\SoftwaresIDES\lib\site-packages\pymysql\err.py:143, in raise_mysql_exception(data)
#     142     errorclass = InternalError if errno < 1000 else OperationalError
# --> 143 raise errorclass(errno, errval)
#
# ProgrammingError: (1146, "Table 'wine_store.purchase' doesn't exist")
#
# The above exception was the direct cause of the following exception:
#
# ProgrammingError                          Traceback (most recent call last)
# Cell In[8], line 22
#      13 example_prompt = PromptTemplate(input_variables=["question", "answer"], template="Question: {question}\n{answer}")
#      15 prompt = FewShotPromptTemplate(
#      16     examples=examples,
#      17     example_prompt=example_prompt,
#      18     suffix="Question: {input}",
#      19     input_variables=["input"]
#      20 )
# ---> 22 db_chain.run(prompt.format(input="What is the mean of the Volume column in the purchasepricesdec table?"))
#
# File ~\SoftwaresIDES\lib\site-packages\langchain\chains\base.py:440, in Chain.run(self, callbacks, tags, metadata, *args, **kwargs)
#     438     if len(args) != 1:
#     439         raise ValueError("`run` supports only one positional argument.")
# --> 440     return self(args[0], callbacks=callbacks, tags=tags, metadata=metadata)[
#     441         _output_key
#     442     ]
#     444 if kwargs and not args:
#     445     return self(kwargs, callbacks=callbacks, tags=tags, metadata=metadata)[
#     446         _output_key
#     447     ]
#
# File ~\SoftwaresIDES\lib\site-packages\langchain\chains\base.py:243, in Chain.__call__(self, inputs, return_only_outputs, callbacks, tags, metadata, include_run_info)
#     241 except (KeyboardInterrupt, Exception) as e:
#     242     run_manager.on_chain_error(e)
# --> 243     raise e
#     244 run_manager.on_chain_end(outputs)
#     245 final_outputs: Dict[str, Any] = self.prep_outputs(
#     246     inputs, outputs, return_only_outputs
#     247 )
#
# File ~\SoftwaresIDES\lib\site-packages\langchain\chains\base.py:237, in Chain.__call__(self, inputs, return_only_outputs, callbacks, tags, metadata, include_run_info)
#     231 run_manager = callback_manager.on_chain_start(
#     232     dumpd(self),
#     233     inputs,
#     234 )
#     235 try:
#     236     outputs = (
# --> 237         self._call(inputs, run_manager=run_manager)
#     238         if new_arg_supported
#     239         else self._call(inputs)
#     240     )
#     241 except (KeyboardInterrupt, Exception) as e:
#     242     run_manager.on_chain_error(e)
#
# File ~\SoftwaresIDES\lib\site-packages\langchain\chains\sql_database\base.py:181, in SQLDatabaseChain._call(self, inputs, run_manager)
#     177 except Exception as exc:
#     178     # Append intermediate steps to exception, to aid in logging and later
#     179     # improvement of few shot prompt seeds
#     180     exc.intermediate_steps = intermediate_steps  # type: ignore
# --> 181     raise exc
#
# File ~\SoftwaresIDES\lib\site-packages\langchain\chains\sql_database\base.py:126, in SQLDatabaseChain._call(self, inputs, run_manager)
#     122     intermediate_steps.append(
#     123         sql_cmd
#     124     )  # output: sql generation (no checker)
#     125     intermediate_steps.append({"sql_cmd": sql_cmd})  # input: sql exec
# --> 126     result = self.database.run(sql_cmd)
#     127     intermediate_steps.append(str(result))  # output: sql exec
#     128 else:
#
# File ~\SoftwaresIDES\lib\site-packages\langchain\sql_database.py:390, in SQLDatabase.run(self, command, fetch)
#     388     else:
#     389         connection.exec_driver_sql(f"SET search_path TO {self._schema}")
# --> 390 cursor = connection.execute(text(command))
#     391 if cursor.returns_rows:
#     392     if fetch == "all":
#
# File ~\SoftwaresIDES\lib\site-packages\sqlalchemy\engine\base.py:1306, in Connection.execute(self, statement, *multiparams, **params)
#    1302     util.raise_(
#    1303         exc.ObjectNotExecutableError(statement), replace_context=err
#    1304     )
#    1305 else:
# -> 1306     return meth(self, multiparams, params, _EMPTY_EXECUTION_OPTS)
#
# File ~\SoftwaresIDES\lib\site-packages\sqlalchemy\sql\elements.py:332, in ClauseElement._execute_on_connection(self, connection, multiparams, params, execution_options, _force)
#     328 def _execute_on_connection(
#     329     self, connection, multiparams, params, execution_options, _force=False
#     330 ):
#     331     if _force or self.supports_execution:
# --> 332         return connection._execute_clauseelement(
#     333             self, multiparams, params, execution_options
#     334         )
#     335     else:
#     336         raise exc.ObjectNotExecutableError(self)
#
# File ~\SoftwaresIDES\lib\site-packages\sqlalchemy\engine\base.py:1498, in Connection._execute_clauseelement(self, elem, multiparams, params, execution_options)
#    1486 compiled_cache = execution_options.get(
#    1487     "compiled_cache", self.engine._compiled_cache
#    1488 )
#    1490 compiled_sql, extracted_params, cache_hit = elem._compile_w_cache(
#    1491     dialect=dialect,
#    1492     compiled_cache=compiled_cache,
#    (...)
#    1496     linting=self.dialect.compiler_linting | compiler.WARN_LINTING,
#    1497 )
# -> 1498 ret = self._execute_context(
#    1499     dialect,
#    1500     dialect.execution_ctx_cls._init_compiled,
#    1501     compiled_sql,
#    1502     distilled_params,
#    1503     execution_options,
#    1504     compiled_sql,
#    1505     distilled_params,
#    1506     elem,
#    1507     extracted_params,
#    1508     cache_hit=cache_hit,
#    1509 )
#    1510 if has_events:
#    1511     self.dispatch.after_execute(
#    1512         self,
#    1513         elem,
#    (...)
#    1517         ret,
#    1518     )
#
# File ~\SoftwaresIDES\lib\site-packages\sqlalchemy\engine\base.py:1862, in Connection._execute_context(self, dialect, constructor, statement, parameters, execution_options, *args, **kw)
#    1859             branched.close()
#    1861 except BaseException as e:
# -> 1862     self._handle_dbapi_exception(
#    1863         e, statement, parameters, cursor, context
#    1864     )
#    1866 return result
#
# File ~\SoftwaresIDES\lib\site-packages\sqlalchemy\engine\base.py:2043, in Connection._handle_dbapi_exception(self, e, statement, parameters, cursor, context)
#    2041     util.raise_(newraise, with_traceback=exc_info[2], from_=e)
#    2042 elif should_wrap:
# -> 2043     util.raise_(
#    2044         sqlalchemy_exception, with_traceback=exc_info[2], from_=e
#    2045     )
#    2046 else:
#    2047     util.raise_(exc_info[1], with_traceback=exc_info[2])
#
# File ~\SoftwaresIDES\lib\site-packages\sqlalchemy\util\compat.py:208, in raise_(***failed resolving arguments***)
#     205     exception.__cause__ = replace_context
#     207 try:
# --> 208     raise exception
#     209 finally:
#     210     # credit to
#     211     # https://cosmicpercolator.com/2016/01/13/exception-leaks-in-python-2-and-3/
#     212     # as the __traceback__ object creates a cycle
#     213     del exception, replace_context, from_, with_traceback
#
# File ~\SoftwaresIDES\lib\site-packages\sqlalchemy\engine\base.py:1819, in Connection._execute_context(self, dialect, constructor, statement, parameters, execution_options, *args, **kw)
#    1817                 break
#    1818     if not evt_handled:
# -> 1819         self.dialect.do_execute(
#    1820             cursor, statement, parameters, context
#    1821         )
#    1823 if self._has_events or self.engine._has_events:
#    1824     self.dispatch.after_cursor_execute(
#    1825         self,
#    1826         cursor,
#    (...)
#    1830         context.executemany,
#    1831     )
#
# File ~\SoftwaresIDES\lib\site-packages\sqlalchemy\engine\default.py:732, in DefaultDialect.do_execute(self, cursor, statement, parameters, context)
#     731 def do_execute(self, cursor, statement, parameters, context=None):
# --> 732     cursor.execute(statement, parameters)
#
# File ~\SoftwaresIDES\lib\site-packages\pymysql\cursors.py:148, in Cursor.execute(self, query, args)
#     144     pass
#     146 query = self.mogrify(query, args)
# --> 148 result = self._query(query)
#     149 self._executed = query
#     150 return result
#
# File ~\SoftwaresIDES\lib\site-packages\pymysql\cursors.py:310, in Cursor._query(self, q)
#     308 self._last_executed = q
#     309 self._clear_result()
# --> 310 conn.query(q)
#     311 self._do_get_result()
#     312 return self.rowcount
#
# File ~\SoftwaresIDES\lib\site-packages\pymysql\connections.py:548, in Connection.query(self, sql, unbuffered)
#     546     sql = sql.encode(self.encoding, "surrogateescape")
#     547 self._execute_command(COMMAND.COM_QUERY, sql)
# --> 548 self._affected_rows = self._read_query_result(unbuffered=unbuffered)
#     549 return self._affected_rows
#
# File ~\SoftwaresIDES\lib\site-packages\pymysql\connections.py:775, in Connection._read_query_result(self, unbuffered)
#     773 else:
#     774     result = MySQLResult(self)
# --> 775     result.read()
#     776 self._result = result
#     777 if result.server_status is not None:
#
# File ~\SoftwaresIDES\lib\site-packages\pymysql\connections.py:1156, in MySQLResult.read(self)
#    1154 def read(self):
#    1155     try:
# -> 1156         first_packet = self.connection._read_packet()
#    1158         if first_packet.is_ok_packet():
#    1159             self._read_ok_packet(first_packet)
#
# File ~\SoftwaresIDES\lib\site-packages\pymysql\connections.py:725, in Connection._read_packet(self, packet_type)
#     723     if self._result is not None and self._result.unbuffered_active is True:
#     724         self._result.unbuffered_active = False
# --> 725     packet.raise_for_error()
#     726 return packet
#
# File ~\SoftwaresIDES\lib\site-packages\pymysql\protocol.py:221, in MysqlPacket.raise_for_error(self)
#     219 if DEBUG:
#     220     print("errno =", errno)
# --> 221 err.raise_mysql_exception(self._data)
#
# File ~\SoftwaresIDES\lib\site-packages\pymysql\err.py:143, in raise_mysql_exception(data)
#     141 if errorclass is None:
#     142     errorclass = InternalError if errno < 1000 else OperationalError
# --> 143 raise errorclass(errno, errval)
#
# ProgrammingError: (pymysql.err.ProgrammingError) (1146, "Table 'wine_store.purchase' doesn't exist")
# [SQL: SELECT avg(T1.PurchasePrice) FROM purchase]
# (Background on this error at: https://sqlalche.me/e/14/f405)

# %% [markdown]
# ### RAG model:

# %% [markdown]
# #### Using WikiSQL dataset for the retrieval queries. Create a vector database (FAISS indexed) of the csv file by embedding the csv and use the similarity search feature to query the LLM.

# %%
input_data = pd.read_csv(r"C:\Users\Rutvik\LLM_SQL\train\train_text2sql.csv")
input_data.head()
# Out:
#                                             question  \
# 0    Tell me what the notes are for South Australia
# 1  What is the current series where the new serie...
# 2            What is the format for South Australia?
# 3  Name the background colour for the Australian ...
# 4      how many times is the fuel propulsion is cng?
#
#                                                  sql
# 0  SELECT Notes FROM table WHERE Current slogan =...
# 1  SELECT Current series FROM table WHERE Notes =...
# 2  SELECT Format FROM table WHERE State/territory...
# 3  SELECT Text/background colour FROM table WHERE...
# 4  SELECT COUNT Fleet Series (Quantity) FROM tabl...

# %%
# Using only 0.01 of the 54,000 rows of the train dataset as the embeddings is taking a long time.
#input_df = input_data.sample(frac=0.01)
#input_df.to_csv(r"C:\Users\Rutvik\LLM_SQL\train\train_text2sql_small.csv", index=False)

# %%
nl_and_sql = CSVLoader(file_path=r"C:\Users\Rutvik\LLM_SQL\train\train_text2sql_small.csv", encoding="utf8")
docs = nl_and_sql.load()
docs
# Out:
# [Document(page_content='question: How many different countries did the champion Se Ri Pak (2) represent?\nsql: SELECT COUNT Country FROM table WHERE Champion = Se Ri Pak (2)', metadata={'source': 'C:\\Users\\Rutvik\\LLM_SQL\\train\\train_text2sql_small.csv', 'row': 0}),
#  Document(page_content='question: On what date is Jerilyn Britz the runner-up?\nsql: SELECT Date FROM table WHERE Runner(s)-up = jerilyn britz', metadata={'source': 'C:\\Users\\Rutvik\\LLM_SQL\\train\\train_text2sql_small.csv', 'row': 1}),
#  Document(page_content='question: What is the fixed charge for the user who had a tariff of 11.30?\nsql: SELECT Fixed Charge ( Rs. /kWh) FROM table WHERE Tariff ( Rs. /kWh) = 11.30', metadata={'source': 'C:\\Users\\Rutvik\\LLM_SQL\\train\\train_text2sql_small.csv', 'row': 2}),
#  Document(page_content='question: How many people voted in Cabarrus county?\nsql: SELECT MIN Total FROM table WHERE County = Cabarrus', metadata={'source': 'C:\\Users\\Rutvik\\LLM_SQL\\train\\train_text2sql_small.csv', 'row': 3}),
#  Document(page_content='question: What is the sum for December that has 0.36 in July, and lager than 0.35000000000000003 in February?\nsql: SELECT SUM December FROM table WHERE July = 0.36 AND February > 0.35000000000000003', metadata={'source': 'C:\\Users\\Rutvik\\LLM_SQL\\train\\train_text2sql_small.csv', 'row': 4}),
#  Document(page_content='question: In which round was Gabriel Veiga the opponent?\nsql: SELECT Round FROM table WHERE Opponent = gabriel veiga', metadata={'source': 'C:\\Users\\Rutvik\\LLM_SQL\\train\\train_text2sql_small.csv', 'row': 5}),
#  Document(page_content='question: How many new entries are there for a second phase that has 4 winners from previous rounds?\nsql: SELECT New entries this round FROM table WHERE Phase = second phase AND Winners from previous round = 4', metadata={'source': 'C:\\Users\\Rutvik\\LLM_SQL\\train\\train_text2sql_small.csv', 'row': 6}),
#  Document(page_content='question: What away team has a score of 12.10 (82)?\nsql: SELECT Away team FROM table WHERE Away team score = 12.10 (82)', metadata={'source': 'C:\\Users\\Rutvik\\LLM_SQL\\train\\train_text2sql_small.csv', 'row': 7}),
#  Document(page_content='question: Who won the gold in 1958?\nsql: SELECT Gold FROM table WHERE Year = 1958', metadata={'source': 'C:\\Users\\Rutvik\\LLM_SQL\\train\\train_text2sql_small.csv', 'row': 8}),
#  Document(page_content='question: When did the duchess, who was married to philippe, die?\nsql: SELECT Death FROM table WHERE Spouse = philippe', metadata={'source': 'C:\\Users\\Rutvik\\LLM_SQL\\train\\train_text2sql_small.csv', 'row': 9}),
#  Document(page_content='question: What is the character for 2005?\nsql: SELECT Character FROM table WHERE Year = 2005', metadata={'source': 'C:\\Users\\Rutvik\\LLM_SQL\\train\\train_text2sql_small.csv', 'row': 10}),
#  Document(page_content='question: Which song directed by datta naik had the ending stranza written by Johnny Walker?\nsql: SELECT Additional Info FROM table WHERE Music Director = Datta Naik', metadata={'source': 'C:\\Users\\Rutvik\\LLM_SQL\\train\\train_text2sql_small.csv', 'row': 11}),
#  Document(page_content='question: What is the latest Date, when Label is Captain Oi! Records?\nsql: SELECT MAX Date FROM table WHERE Label = captain oi! records', metadata={'source': 'C:\\Users\\Rutvik\\LLM_SQL\\train\\train_text2sql_small.csv', 'row': 12}),
#  Document(page_content='question: Name the saka era for sign of zodiac being pisces\nsql: SELECT Saka era FROM table WHERE Sign of Zodiac = Pisces', metadata={'source': 'C:\\Users\\Rutvik\\LLM_SQL\\train\\train_text2sql_small.csv', 'row': 13}),
#  Document(page_content='question: What is Tournament, when Date is "9 August 1993"?\nsql: SELECT Tournament FROM table WHERE Date = 9 august 1993', metadata={'source': 'C:\\Users\\Rutvik\\LLM_SQL\\train\\train_text2sql_small.csv', 'row': 14}),
#  Document(page_content='question: When davao city is the  home or representative town or province and clash 2010 is the edition how many ages are there?\nsql: SELECT COUNT Age FROM table WHERE Edition = Clash 2010 AND Home or representative town or province = Davao City', metadata={'source': 'C:\\Users\\Rutvik\\LLM_SQL\\train\\train_text2sql_small.csv', 'row': 15}),
#  Document(page_content='question: List all home teams when Western Kentucky was the visiting team.\nsql: SELECT Home team FROM table WHERE Visiting team = Western Kentucky', metadata={'source': 'C:\\Users\\Rutvik\\LLM_SQL\\train\\train_text2sql_small.csv', 'row': 16}),
#  Document(page_content='question: What is the name of the player when n is 28?\nsql: SELECT Name FROM table WHERE N = 28', metadata={'source': 'C:\\Users\\Rutvik\\LLM_SQL\\train\\train_text2sql_small.csv', 'row': 17}),
#  Document(page_content='question: Which date has a Score of 4–6, 2–6?\nsql: SELECT Date FROM table WHERE Score = 4–6, 2–6', metadata={'source': 'C:\\Users\\Rutvik\\LLM_SQL\\train\\train_text2sql_small.csv', 'row': 18}),
#  Document(page_content='question: What was the first numbered episode in the series titled "the wind beneath our wings"?\nsql: SELECT MIN Series # FROM table WHERE Title = "The Wind Beneath Our Wings"', metadata={'source': 'C:\\Users\\Rutvik\\LLM_SQL\\train\\train_text2sql_small.csv', 'row': 19}),
#  Document(page_content='question: Who had the highest assists during the game on February 22?\nsql: SELECT High assists FROM table WHERE Date = february 22', metadata={'source': 'C:\\Users\\Rutvik\\LLM_SQL\\train\\train_text2sql_small.csv', 'row': 20}),
#  Document(page_content='question: What is the sum of people in attendance on September 8?\nsql: SELECT SUM Attendance FROM table WHERE Date = september 8', metadata={'source': 'C:\\Users\\Rutvik\\LLM_SQL\\train\\train_text2sql_small.csv', 'row': 21}),
#  Document(page_content='question: What is the ICAO for Air Busan?\nsql: SELECT ICAO FROM table WHERE CALLSIGN = air busan', metadata={'source': 'C:\\Users\\Rutvik\\LLM_SQL\\train\\train_text2sql_small.csv', 'row': 22}),
#  Document(page_content='question: How many races were there when Sigachev had 38 points?\nsql: SELECT MIN Races FROM table WHERE Points = 38', metadata={'source': 'C:\\Users\\Rutvik\\LLM_SQL\\train\\train_text2sql_small.csv', 'row': 23}),
#  Document(page_content='question: Tell me the doubles W-L for player of laurynas grigelis\nsql: SELECT Doubles W–L FROM table WHERE Player = laurynas grigelis', metadata={'source': 'C:\\Users\\Rutvik\\LLM_SQL\\train\\train_text2sql_small.csv', 'row': 24}),
#  Document(page_content='question: what is the points total for forti corse?\nsql: SELECT SUM Points FROM table WHERE Entrant = forti corse', metadata={'source': 'C:\\Users\\Rutvik\\LLM_SQL\\train\\train_text2sql_small.csv', 'row': 25}),
#  Document(page_content='question: Which league is for baseball with Laredo Apaches?\nsql: SELECT League FROM table WHERE Sport = baseball AND Club = laredo apaches', metadata={'source': 'C:\\Users\\Rutvik\\LLM_SQL\\train\\train_text2sql_small.csv', 'row': 26}),
#  Document(page_content='question: What date is week 3?\nsql: SELECT Date FROM table WHERE Week = 3', metadata={'source': 'C:\\Users\\Rutvik\\LLM_SQL\\train\\train_text2sql_small.csv', 'row': 27}),
#  Document(page_content='question: what is the meaning of the latin day name "dies saturni"?\nsql: SELECT Latin day name meaning FROM table WHERE Glossed from Latin day name = Dies Saturni', metadata={'source': 'C:\\Users\\Rutvik\\LLM_SQL\\train\\train_text2sql_small.csv', 'row': 28}),
#  Document(page_content='question: What is the Season when the Opponent was zenit st. petersburg?\nsql: SELECT Season FROM table WHERE Opponent = zenit st. petersburg', metadata={'source': 'C:\\Users\\Rutvik\\LLM_SQL\\train\\train_text2sql_small.csv', 'row': 29}),
#  Document(page_content='question: Name the position for jordan cameron\nsql: SELECT Position FROM table WHERE Player = Jordan Cameron', metadata={'source': 'C:\\Users\\Rutvik\\LLM_SQL\\train\\train_text2sql_small.csv', 'row': 30}),
#  Document(page_content='question: What is the model of the engine d5244 t7?\nsql: SELECT Model name FROM table WHERE Engine code = D5244 T7', metadata={'source': 'C:\\Users\\Rutvik\\LLM_SQL\\train\\train_text2sql_small.csv', 'row': 31}),
#  Document(page_content='question: How many poles did team #14 ginn racing have?\nsql: SELECT Poles FROM table WHERE Team(s) = #14 Ginn Racing', metadata={'source': 'C:\\Users\\Rutvik\\LLM_SQL\\train\\train_text2sql_small.csv', 'row': 32}),
#  Document(page_content='question: In which week was the attendance 47,218?\nsql: SELECT SUM Week FROM table WHERE Attendance = 47,218', metadata={'source': 'C:\\Users\\Rutvik\\LLM_SQL\\train\\train_text2sql_small.csv', 'row': 33}),
#  Document(page_content='question: What clubs are in the evgrapi shevardnadze stadium?\nsql: SELECT Clubs FROM table WHERE Stadium = evgrapi shevardnadze stadium', metadata={'source': 'C:\\Users\\Rutvik\\LLM_SQL\\train\\train_text2sql_small.csv', 'row': 34}),
#  Document(page_content='question: At the rate where 1000 kwh/kwp•y is 26.0, what is the value of 1600 kwh/kwp•y?\nsql: SELECT 1600 kWh/kWp•y FROM table WHERE 1000 kWh/kWp•y = 26.0', metadata={'source': 'C:\\Users\\Rutvik\\LLM_SQL\\train\\train_text2sql_small.csv', 'row': 35}),
#  Document(page_content='question: What is the number of wins when scored was less than 26, and conceded was larger than 23?\nsql: SELECT SUM Wins FROM table WHERE Scored < 26 AND Conceded > 23', metadata={'source': 'C:\\Users\\Rutvik\\LLM_SQL\\train\\train_text2sql_small.csv', 'row': 36}),
#  Document(page_content='question: When 21 is the number in series what is the air date?\nsql: SELECT Original air date FROM table WHERE No. in series = 21', metadata={'source': 'C:\\Users\\Rutvik\\LLM_SQL\\train\\train_text2sql_small.csv', 'row': 37}),
#  Document(page_content='question: How many U.S Viewers, in millions, were for series # 26?\nsql: SELECT U.S. viewers (millions) FROM table WHERE Series # = 26', metadata={'source': 'C:\\Users\\Rutvik\\LLM_SQL\\train\\train_text2sql_small.csv', 'row': 38}),
#  Document(page_content='question: What was the method used when the time was 4:52?\nsql: SELECT Method FROM table WHERE Time = 4:52', metadata={'source': 'C:\\Users\\Rutvik\\LLM_SQL\\train\\train_text2sql_small.csv', 'row': 39}),
#  Document(page_content='question: Which Apogee has a Mission of maxus 3?\nsql: SELECT Apogee FROM table WHERE Mission = maxus 3', metadata={'source': 'C:\\Users\\Rutvik\\LLM_SQL\\train\\train_text2sql_small.csv', 'row': 40}),
#  Document(page_content='question: Which Losses have a Season larger than 1941, and a Team of hamilton wildcats, and Ties of 0?\nsql: SELECT Losses FROM table WHERE Season > 1941 AND Team = hamilton wildcats AND Ties = 0', metadata={'source': 'C:\\Users\\Rutvik\\LLM_SQL\\train\\train_text2sql_small.csv', 'row': 41}),
#  Document(page_content="question: Who is Doug Basham's team?\nsql: SELECT Team FROM table WHERE Wrestler = doug basham", metadata={'source': 'C:\\Users\\Rutvik\\LLM_SQL\\train\\train_text2sql_small.csv', 'row': 42}),
#  Document(page_content='question: What team had a pick of 24 and an overall pick of 310?\nsql: SELECT School/Club Team FROM table WHERE Pick = 24 AND Overall Pick = 310', metadata={'source': 'C:\\Users\\Rutvik\\LLM_SQL\\train\\train_text2sql_small.csv', 'row': 43}),
#  Document(page_content='question: Who won 3rd place when the mutya ng pilipinas winner was  was rochelle romero ong?\nsql: SELECT 2nd runner-up FROM table WHERE Mutya ng Pilipinas Asia Pacific = Rochelle Romero Ong', metadata={'source': 'C:\\Users\\Rutvik\\LLM_SQL\\train\\train_text2sql_small.csv', 'row': 44}),
#  Document(page_content='question: What is the Location for the buick-goodwrench open?\nsql: SELECT Location FROM table WHERE Tournament = buick-goodwrench open', metadata={'source': 'C:\\Users\\Rutvik\\LLM_SQL\\train\\train_text2sql_small.csv', 'row': 45}),
#  Document(page_content="question: What was the Women's doubles that has a Men's singles of fernando silva, and in the year 1996?\nsql: SELECT Women's doubles FROM table WHERE Men's singles = fernando silva AND Year < 1996", metadata={'source': 'C:\\Users\\Rutvik\\LLM_SQL\\train\\train_text2sql_small.csv', 'row': 46}),
#  Document(page_content='question: In what tournament was the winning score 68-67-65-66=266?\nsql: SELECT Tournament FROM table WHERE Winning score = 68-67-65-66=266', metadata={'source': 'C:\\Users\\Rutvik\\LLM_SQL\\train\\train_text2sql_small.csv', 'row': 47}),
#  Document(page_content='question: What is the score on 23 November 1983 with exeter city as the away team?\nsql: SELECT Score FROM table WHERE Date = 23 november 1983 AND Away team = exeter city', metadata={'source': 'C:\\Users\\Rutvik\\LLM_SQL\\train\\train_text2sql_small.csv', 'row': 48}),
#  Document(page_content='question: What is the 2000 number when the 1989 is less than 54.9 in Arizona, New Mexico, and Utah?\nsql: SELECT SUM 2000 FROM table WHERE 1989 < 54.9 AND Location = arizona, new mexico, and utah', metadata={'source': 'C:\\Users\\Rutvik\\LLM_SQL\\train\\train_text2sql_small.csv', 'row': 49}),
#  Document(page_content='question: What Time has Date of May 9?\nsql: SELECT Time FROM table WHERE Date = may 9', metadata={'source': 'C:\\Users\\Rutvik\\LLM_SQL\\train\\train_text2sql_small.csv', 'row': 50}),
#  Document(page_content='question: What is the prize money for Virginia?\nsql: SELECT 1st Prize( $ ) FROM table WHERE Location = Virginia', metadata={'source': 'C:\\Users\\Rutvik\\LLM_SQL\\train\\train_text2sql_small.csv', 'row': 51}),
#  Document(page_content='question: What is the best top 10 when there are fewer than 0 wins?\nsql: SELECT MAX Top 10s FROM table WHERE Wins < 0', metadata={'source': 'C:\\Users\\Rutvik\\LLM_SQL\\train\\train_text2sql_small.csv', 'row': 52}),
#  Document(page_content='question: What language was the film Pelle Erobreren, which received the best actor nomination, in?\nsql: SELECT Language FROM table WHERE Category = best actor AND Original title = pelle erobreren', metadata={'source': 'C:\\Users\\Rutvik\\LLM_SQL\\train\\train_text2sql_small.csv', 'row': 53}),
#  Document(page_content='question: What is the report for 10 october?\nsql: SELECT Report FROM table WHERE Date = 10 october', metadata={'source': 'C:\\Users\\Rutvik\\LLM_SQL\\train\\train_text2sql_small.csv', 'row': 54}),
#  Document(page_content='question: Which points classification was used in stage 15?\nsql: SELECT Points classification FROM table WHERE Stage = 15', metadata={'source': 'C:\\Users\\Rutvik\\LLM_SQL\\train\\train_text2sql_small.csv', 'row': 55}),
#  Document(page_content='question: Name the scott for chloropsis hardwickii\nsql: SELECT Scott FROM table WHERE Species = Chloropsis hardwickii', metadata={'source': 'C:\\Users\\Rutvik\\LLM_SQL\\train\\train_text2sql_small.csv', 'row': 56}),
#  Document(page_content='question: what is the school that left in 1966?\nsql: SELECT School FROM table WHERE Year Left = 1966', metadata={'source': 'C:\\Users\\Rutvik\\LLM_SQL\\train\\train_text2sql_small.csv', 'row': 57}),
#  Document(page_content='question: What is the highest points value for the 500cc class in years after 1962 with 0 wins?\nsql: SELECT MAX Points FROM table WHERE Class = 500cc AND Year > 1962 AND Wins < 0', metadata={'source': 'C:\\Users\\Rutvik\\LLM_SQL\\train\\train_text2sql_small.csv', 'row': 58}),
#  Document(page_content='question: Who is the manufacturer when 150.088 is the average speed (mph)?\nsql: SELECT Manufacturer FROM table WHERE Average Speed (mph) = 150.088', metadata={'source': 'C:\\Users\\Rutvik\\LLM_SQL\\train\\train_text2sql_small.csv', 'row': 59}),
#  Document(page_content='question: How many average total matches have league cup as the competition, with a draw greater than 0?\nsql: SELECT AVG Total Matches FROM table WHERE Competition = league cup AND Draw > 0', metadata={'source': 'C:\\Users\\Rutvik\\LLM_SQL\\train\\train_text2sql_small.csv', 'row': 60}),
#  Document(page_content='question: What district was John Dawson from?\nsql: SELECT District FROM table WHERE Incumbent = John Dawson', metadata={'source': 'C:\\Users\\Rutvik\\LLM_SQL\\train\\train_text2sql_small.csv', 'row': 61}),
#  Document(page_content='question: What position did pick 36 play?\nsql: SELECT Position FROM table WHERE Pick = 36', metadata={'source': 'C:\\Users\\Rutvik\\LLM_SQL\\train\\train_text2sql_small.csv', 'row': 62}),
#  Document(page_content='question: What time did the game start on saturday, april 20?\nsql: SELECT Kickoff FROM table WHERE Date = Saturday, April 20', metadata={'source': 'C:\\Users\\Rutvik\\LLM_SQL\\train\\train_text2sql_small.csv', 'row': 63}),
#  Document(page_content='question: What is the Score on November 23, 1946 with Washington Capitols Home team?\nsql: SELECT Score FROM table WHERE Home = washington capitols AND Date = november 23, 1946', metadata={'source': 'C:\\Users\\Rutvik\\LLM_SQL\\train\\train_text2sql_small.csv', 'row': 64}),
#  Document(page_content='question: What was the record after game 45?\nsql: SELECT Record FROM table WHERE Game = 45', metadata={'source': 'C:\\Users\\Rutvik\\LLM_SQL\\train\\train_text2sql_small.csv', 'row': 65}),
#  Document(page_content='question: What is the lowest bronze number when silver shows 2, and the total is 8?\nsql: SELECT MIN Bronze FROM table WHERE Silver = 2 AND Total = 8', metadata={'source': 'C:\\Users\\Rutvik\\LLM_SQL\\train\\train_text2sql_small.csv', 'row': 66}),
#  Document(page_content='question: What state has Richard Foster as a member?\nsql: SELECT State FROM table WHERE Member = richard foster', metadata={'source': 'C:\\Users\\Rutvik\\LLM_SQL\\train\\train_text2sql_small.csv', 'row': 67}),
#  Document(page_content='question: What is the points number when rebounds is 4.4?\nsql: SELECT Points FROM table WHERE Rebounds = 4.4', metadata={'source': 'C:\\Users\\Rutvik\\LLM_SQL\\train\\train_text2sql_small.csv', 'row': 68}),
#  Document(page_content='question: What was the crowd attendance for the game with an away team score of 14.10 (94)?\nsql: SELECT SUM Crowd FROM table WHERE Away team score = 14.10 (94)', metadata={'source': 'C:\\Users\\Rutvik\\LLM_SQL\\train\\train_text2sql_small.csv', 'row': 69}),
#  Document(page_content='question: What is the competition that had a 2-2 result?\nsql: SELECT Competition FROM table WHERE Result = 2-2', metadata={'source': 'C:\\Users\\Rutvik\\LLM_SQL\\train\\train_text2sql_small.csv', 'row': 70}),
#  Document(page_content="question: What was actor Teresa Graves's series before the year 1993?\nsql: SELECT Series FROM table WHERE Year < 1993 AND Actor = teresa graves", metadata={'source': 'C:\\Users\\Rutvik\\LLM_SQL\\train\\train_text2sql_small.csv', 'row': 71}),
#  Document(page_content='question: What shows for House 1950 when the Governors 1950 show governors 1995?\nsql: SELECT House 1950 FROM table WHERE Governors 1950 = governors 1995', metadata={'source': 'C:\\Users\\Rutvik\\LLM_SQL\\train\\train_text2sql_small.csv', 'row': 72}),
#  Document(page_content='question: Name the total number of total with silver of 6, bronze more than 5 and gold less than 4\nsql: SELECT COUNT Total FROM table WHERE Silver = 6 AND Bronze > 5 AND Gold < 4', metadata={'source': 'C:\\Users\\Rutvik\\LLM_SQL\\train\\train_text2sql_small.csv', 'row': 73}),
#  Document(page_content='question: Which player went to Michigan State?\nsql: SELECT Player name FROM table WHERE College = Michigan State', metadata={'source': 'C:\\Users\\Rutvik\\LLM_SQL\\train\\train_text2sql_small.csv', 'row': 74}),
#  Document(page_content='question: What is the name of the Winner in north carolina at the greater greensboro open?\nsql: SELECT Winner FROM table WHERE Location = north carolina AND Tournament = greater greensboro open', metadata={'source': 'C:\\Users\\Rutvik\\LLM_SQL\\train\\train_text2sql_small.csv', 'row': 75}),
#  Document(page_content='question: What is the state of the city of denver, which has a rank less than 10?\nsql: SELECT State FROM table WHERE Rank < 10 AND City = denver', metadata={'source': 'C:\\Users\\Rutvik\\LLM_SQL\\train\\train_text2sql_small.csv', 'row': 76}),
#  Document(page_content='question: What location did the team win before 1998 in the europe/africa zone, group i, round robin?\nsql: SELECT Location FROM table WHERE Competition = europe/africa zone, group i, round robin AND Result = win AND Year < 1998', metadata={'source': 'C:\\Users\\Rutvik\\LLM_SQL\\train\\train_text2sql_small.csv', 'row': 77}),
#  Document(page_content='question: What is the earliest season with a regular season standing of 11th from 15 and more than 10 wins?\nsql: SELECT MIN Season FROM table WHERE Regular Season Standing = 11th from 15 AND Wins > 10', metadata={'source': 'C:\\Users\\Rutvik\\LLM_SQL\\train\\train_text2sql_small.csv', 'row': 78}),
#  Document(page_content='question: What state had an active chapter from 1906-1991?\nsql: SELECT State FROM table WHERE Charter Range = 1906-1991', metadata={'source': 'C:\\Users\\Rutvik\\LLM_SQL\\train\\train_text2sql_small.csv', 'row': 79}),
#  Document(page_content='question: How many seconds is a shuttle run that give 2 points?\nsql: SELECT Shuttle Run (sec) FROM table WHERE Points = 2', metadata={'source': 'C:\\Users\\Rutvik\\LLM_SQL\\train\\train_text2sql_small.csv', 'row': 80}),
#  Document(page_content='question: What is Source Version, when License is LGPL or MPL?\nsql: SELECT Source Version FROM table WHERE License = lgpl or mpl', metadata={'source': 'C:\\Users\\Rutvik\\LLM_SQL\\train\\train_text2sql_small.csv', 'row': 81}),
#  Document(page_content='question: How many races went for 10 rounds?\nsql: SELECT COUNT Fastest lap FROM table WHERE Rnd = 10', metadata={'source': 'C:\\Users\\Rutvik\\LLM_SQL\\train\\train_text2sql_small.csv', 'row': 82}),
#  Document(page_content='question: Which manufacturer has more than 28 laps and less than 9 grids with jeremy mcwilliams?\nsql: SELECT Manufacturer FROM table WHERE Laps < 28 AND Grid < 9 AND Rider = jeremy mcwilliams', metadata={'source': 'C:\\Users\\Rutvik\\LLM_SQL\\train\\train_text2sql_small.csv', 'row': 83}),
#  Document(page_content='question: what is the number of times that the heat is 3 and the name is cxhristy ekpukhon ihunaegbo?\nsql: SELECT COUNT Lane FROM table WHERE Heat = 3 AND Name = cxhristy ekpukhon ihunaegbo', metadata={'source': 'C:\\Users\\Rutvik\\LLM_SQL\\train\\train_text2sql_small.csv', 'row': 84}),
#  Document(page_content='question: In game site AOL Arena, who are all the opponents?\nsql: SELECT Opponent FROM table WHERE Game site = AOL Arena', metadata={'source': 'C:\\Users\\Rutvik\\LLM_SQL\\train\\train_text2sql_small.csv', 'row': 85}),
#  Document(page_content='question: What is the total number of draws for Wakool when there are more than 11 losses and fewer than 4 wins?\nsql: SELECT COUNT Draws FROM table WHERE Losses > 11 AND Wins < 4 AND Golden Rivers = wakool', metadata={'source': 'C:\\Users\\Rutvik\\LLM_SQL\\train\\train_text2sql_small.csv', 'row': 86}),
#  Document(page_content='question: Who was the coach who had 215 losses?\nsql: SELECT Coach FROM table WHERE Losses = 215', metadata={'source': 'C:\\Users\\Rutvik\\LLM_SQL\\train\\train_text2sql_small.csv', 'row': 87}),
#  Document(page_content='question: What is the average number of laps when Gerhard Berger is the driver?\nsql: SELECT AVG Laps FROM table WHERE Driver = gerhard berger', metadata={'source': 'C:\\Users\\Rutvik\\LLM_SQL\\train\\train_text2sql_small.csv', 'row': 88}),
#  Document(page_content="question: When the nation of poland had less than 17 medals but more than 1 gold medal, what's the Highest number of bronze medals?\nsql: SELECT MAX Bronze FROM table WHERE Total < 17 AND Nation = poland AND Gold > 1", metadata={'source': 'C:\\Users\\Rutvik\\LLM_SQL\\train\\train_text2sql_small.csv', 'row': 89}),
#  Document(page_content='question: How many nationalities does Tom Colley have?\nsql: SELECT COUNT Nationality FROM table WHERE Player = Tom Colley', metadata={'source': 'C:\\Users\\Rutvik\\LLM_SQL\\train\\train_text2sql_small.csv', 'row': 90}),
#  Document(page_content='question: If the rank is 17, what are the names?\nsql: SELECT Name FROM table WHERE Rank = 17', metadata={'source': 'C:\\Users\\Rutvik\\LLM_SQL\\train\\train_text2sql_small.csv', 'row': 91}),
#  Document(page_content='question: Which Spouse has a Birth of 30 may 1653?\nsql: SELECT Spouse FROM table WHERE Birth = 30 may 1653', metadata={'source': 'C:\\Users\\Rutvik\\LLM_SQL\\train\\train_text2sql_small.csv', 'row': 92}),
#  Document(page_content='question: What Club has 13 wins, goals against less than 48, and a position of 4?\nsql: SELECT Club FROM table WHERE Wins = 13 AND Goals against < 48 AND Position = 4', metadata={'source': 'C:\\Users\\Rutvik\\LLM_SQL\\train\\train_text2sql_small.csv', 'row': 93}),
#  Document(page_content='question: What is the Home team score when the Away team score is 17.16 (118)?\nsql: SELECT Home team score FROM table WHERE Away team score = 17.16 (118)', metadata={'source': 'C:\\Users\\Rutvik\\LLM_SQL\\train\\train_text2sql_small.csv', 'row': 94}),
#  Document(page_content='question: What was the original title of Run for Money?\nsql: SELECT Original title FROM table WHERE Film title used in nomination = Run for Money', metadata={'source': 'C:\\Users\\Rutvik\\LLM_SQL\\train\\train_text2sql_small.csv', 'row': 95}),
#  Document(page_content="question: What time was achieved on Saturday 29th August by the rider who recorded 22' 54.20 98.842mph on Tuesday 25th August?\nsql: SELECT Sat 29 Aug FROM table WHERE Tues 25 Aug = 22' 54.20 98.842mph", metadata={'source': 'C:\\Users\\Rutvik\\LLM_SQL\\train\\train_text2sql_small.csv', 'row': 96}),
#  Document(page_content='question: Who was the away team when Lincoln City was the home team?\nsql: SELECT Away team FROM table WHERE Home team = lincoln city', metadata={'source': 'C:\\Users\\Rutvik\\LLM_SQL\\train\\train_text2sql_small.csv', 'row': 97}),
#  Document(page_content='question: Who is the Runner-up that has a Season less than 2005?\nsql: SELECT Runner-up FROM table WHERE Season < 2005', metadata={'source': 'C:\\Users\\Rutvik\\LLM_SQL\\train\\train_text2sql_small.csv', 'row': 98}),
#  Document(page_content='question: What date was the game against Royal Antwerp?\nsql: SELECT Date FROM table WHERE Opponents = royal antwerp', metadata={'source': 'C:\\Users\\Rutvik\\LLM_SQL\\train\\train_text2sql_small.csv', 'row': 99}),
#  Document(page_content='question: What is the pinyin for the Chinese title 直感一笔?\nsql: SELECT Pinyin FROM table WHERE Chinese Title = 直感一笔', metadata={'source': 'C:\\Users\\Rutvik\\LLM_SQL\\train\\train_text2sql_small.csv', 'row': 100}),
#  Document(page_content='question: Which tournament was Tim Henman the runner-up in?\nsql: SELECT Tournament FROM table WHERE Runner-up = tim henman', metadata={'source': 'C:\\Users\\Rutvik\\LLM_SQL\\train\\train_text2sql_small.csv', 'row': 101}),
#  Document(page_content='question: What is the canton of grande dixence?\nsql: SELECT Canton FROM table WHERE Name = Grande Dixence', metadata={'source': 'C:\\Users\\Rutvik\\LLM_SQL\\train\\train_text2sql_small.csv', 'row': 102}),
#  Document(page_content='question: What is the rank for the man from China with notes of QS?\nsql: SELECT MAX Rank FROM table WHERE Notes = qs AND Country = china', metadata={'source': 'C:\\Users\\Rutvik\\LLM_SQL\\train\\train_text2sql_small.csv', 'row': 103}),
#  Document(page_content='question: What is the Chinese name of the player in Index F10?\nsql: SELECT Chinese Name FROM table WHERE Index = f10', metadata={'source': 'C:\\Users\\Rutvik\\LLM_SQL\\train\\train_text2sql_small.csv', 'row': 104}),
#  Document(page_content='question: How many years was Reasons to be Pretty nominated for best play?\nsql: SELECT COUNT Year FROM table WHERE Category = best play', metadata={'source': 'C:\\Users\\Rutvik\\LLM_SQL\\train\\train_text2sql_small.csv', 'row': 105}),
#  Document(page_content='question: Who was the lyricist for composer Haewon Park?\nsql: SELECT Lyricist(s) FROM table WHERE Composer(s) = haewon park', metadata={'source': 'C:\\Users\\Rutvik\\LLM_SQL\\train\\train_text2sql_small.csv', 'row': 106}),
#  Document(page_content='question: What are the original air date(s) for episodes with production code ipea345a?\nsql: SELECT Original Airdate FROM table WHERE Prod. Code = IPEA345A', metadata={'source': 'C:\\Users\\Rutvik\\LLM_SQL\\train\\train_text2sql_small.csv', 'row': 107}),
#  Document(page_content='question: What is the Game with a Record of 19-15?\nsql: SELECT Game FROM table WHERE Record = 19-15', metadata={'source': 'C:\\Users\\Rutvik\\LLM_SQL\\train\\train_text2sql_small.csv', 'row': 108}),
#  Document(page_content='question: What player has over 1 first apperance and over 32 first team goals?\nsql: SELECT Player FROM table WHERE First-Team Appearances > 1 AND First-Team Goals = 32', metadata={'source': 'C:\\Users\\Rutvik\\LLM_SQL\\train\\train_text2sql_small.csv', 'row': 109}),
#  Document(page_content='question: Which position has a Nationality of united states, and a Player of roger powell?\nsql: SELECT Position FROM table WHERE Nationality = united states AND Player = roger powell', metadata={'source': 'C:\\Users\\Rutvik\\LLM_SQL\\train\\train_text2sql_small.csv', 'row': 110}),
#  Document(page_content='question: What is the lowest Round of joe patterson?\nsql: SELECT MIN Round FROM table WHERE Player = joe patterson', metadata={'source': 'C:\\Users\\Rutvik\\LLM_SQL\\train\\train_text2sql_small.csv', 'row': 111}),
#  Document(page_content='question: Which away team has a tie number of 14?\nsql: SELECT Away team FROM table WHERE Tie no = 14', metadata={'source': 'C:\\Users\\Rutvik\\LLM_SQL\\train\\train_text2sql_small.csv', 'row': 112}),
#  Document(page_content="question: What kind of chassis on the angie's list sponsored car?\nsql: SELECT Chassis FROM table WHERE Primary Sponsor = Angie's List", metadata={'source': 'C:\\Users\\Rutvik\\LLM_SQL\\train\\train_text2sql_small.csv', 'row': 113}),
#  Document(page_content='question: Does the S90i model have bluetooth?\nsql: SELECT Bluetooth FROM table WHERE Model = s90i', metadata={'source': 'C:\\Users\\Rutvik\\LLM_SQL\\train\\train_text2sql_small.csv', 'row': 114}),
#  Document(page_content='question: What is the total number of Goals Scored, when the Team is San Salvador F.C., and when the Points are less than 10?\nsql: SELECT MAX Goals Scored FROM table WHERE Team = san salvador f.c. AND Points < 10', metadata={'source': 'C:\\Users\\Rutvik\\LLM_SQL\\train\\train_text2sql_small.csv', 'row': 115}),
#  Document(page_content='question: Which Pick # has a League from of ontario hockey league, a Nationality of united states, and a Team from of brampton battalion?\nsql: SELECT COUNT Pick # FROM table WHERE League from = ontario hockey league AND Nationality = united states AND Team from = brampton battalion', metadata={'source': 'C:\\Users\\Rutvik\\LLM_SQL\\train\\train_text2sql_small.csv', 'row': 116}),
#  Document(page_content='question: Who is in February where has September is kristine hanson?\nsql: SELECT February FROM table WHERE September = kristine hanson', metadata={'source': 'C:\\Users\\Rutvik\\LLM_SQL\\train\\train_text2sql_small.csv', 'row': 117}),
#  Document(page_content='question: How many average games did Nick Rimando have?\nsql: SELECT AVG Games FROM table WHERE Player = nick rimando', metadata={'source': 'C:\\Users\\Rutvik\\LLM_SQL\\train\\train_text2sql_small.csv', 'row': 118}),
#  Document(page_content='question: Which position had a pick larger than 80 and Walt Mainer as a player?\nsql: SELECT Position FROM table WHERE Pick > 80 AND Player = walt mainer', metadata={'source': 'C:\\Users\\Rutvik\\LLM_SQL\\train\\train_text2sql_small.csv', 'row': 119}),
#  Document(page_content='question: What is the Away team score with north melbourne as home team?\nsql: SELECT Away team score FROM table WHERE Home team = north melbourne', metadata={'source': 'C:\\Users\\Rutvik\\LLM_SQL\\train\\train_text2sql_small.csv', 'row': 120}),
#  Document(page_content='question: What is the screen size and pixel amount of model p5000 when the dimensions are 98×64.5×41?\nsql: SELECT Screen size,pixels FROM table WHERE Dimensions W×H×D (mm) = 98×64.5×41 AND Model = p5000', metadata={'source': 'C:\\Users\\Rutvik\\LLM_SQL\\train\\train_text2sql_small.csv', 'row': 121}),
#  Document(page_content='question: What are the amount of wins when the draws are less than 0 and the against is 1348?\nsql: SELECT MIN Wins FROM table WHERE Against = 1348 AND Draws < 0', metadata={'source': 'C:\\Users\\Rutvik\\LLM_SQL\\train\\train_text2sql_small.csv', 'row': 122}),
#  Document(page_content="question: What was Jim Furyk's score?\nsql: SELECT Score FROM table WHERE Player = jim furyk", metadata={'source': 'C:\\Users\\Rutvik\\LLM_SQL\\train\\train_text2sql_small.csv', 'row': 123}),
#  Document(page_content='question: what year was the memphis event?\nsql: SELECT SUM Year FROM table WHERE Event = memphis', metadata={'source': 'C:\\Users\\Rutvik\\LLM_SQL\\train\\train_text2sql_small.csv', 'row': 124}),
#  Document(page_content='question: When was the game that had Sydney Spirit as the away team?\nsql: SELECT Date FROM table WHERE Away team = sydney spirit', metadata={'source': 'C:\\Users\\Rutvik\\LLM_SQL\\train\\train_text2sql_small.csv', 'row': 125}),
#  Document(page_content='question: Name the air date for andy kindler for donald trump\nsql: SELECT Original air date FROM table WHERE Advocate # 1 = Andy Kindler for Donald Trump', metadata={'source': 'C:\\Users\\Rutvik\\LLM_SQL\\train\\train_text2sql_small.csv', 'row': 126}),
#  Document(page_content='question: Who is the opponent of the match with a method of submission (armbar) and a 9-3-1 record?\nsql: SELECT Opponent FROM table WHERE Method = submission (armbar) AND Record = 9-3-1', metadata={'source': 'C:\\Users\\Rutvik\\LLM_SQL\\train\\train_text2sql_small.csv', 'row': 127}),
#  Document(page_content='question: What is the lowest number of bronze medals received by a nation with fewer than 0 gold medals?\nsql: SELECT MIN Bronze FROM table WHERE Gold < 0', metadata={'source': 'C:\\Users\\Rutvik\\LLM_SQL\\train\\train_text2sql_small.csv', 'row': 128}),
#  Document(page_content='question: Which Altitude (mslm) has a Density (inhabitants/km 2) smaller than 1233, and a Rank of 9th?\nsql: SELECT SUM Altitude (mslm) FROM table WHERE Density (inhabitants/km 2 ) < 1233 AND Rank = 9th', metadata={'source': 'C:\\Users\\Rutvik\\LLM_SQL\\train\\train_text2sql_small.csv', 'row': 129}),
#  Document(page_content='question: What are the mm dimensions of the Plustek Mobileoffice D28 Corporate?\nsql: SELECT dimensions (mm) FROM table WHERE product = Plustek MobileOffice D28 Corporate', metadata={'source': 'C:\\Users\\Rutvik\\LLM_SQL\\train\\train_text2sql_small.csv', 'row': 130}),
#  Document(page_content='question: Makio Inoue dubbed on which character?\nsql: SELECT Character FROM table WHERE Original Japanese = Makio Inoue', metadata={'source': 'C:\\Users\\Rutvik\\LLM_SQL\\train\\train_text2sql_small.csv', 'row': 131}),
#  Document(page_content='question: What is the position of the competition in Tampere, Finland?\nsql: SELECT Position FROM table WHERE Venue = tampere, finland', metadata={'source': 'C:\\Users\\Rutvik\\LLM_SQL\\train\\train_text2sql_small.csv', 'row': 132}),
#  Document(page_content='question: I want the greatest attendance when the opponent is the chicago bears\nsql: SELECT MAX Attendance FROM table WHERE Opponent = chicago bears', metadata={'source': 'C:\\Users\\Rutvik\\LLM_SQL\\train\\train_text2sql_small.csv', 'row': 133}),
#  Document(page_content='question: Name the most obama number for mccain being 38.86%\nsql: SELECT MAX Obama# FROM table WHERE McCain% = 38.86%', metadata={'source': 'C:\\Users\\Rutvik\\LLM_SQL\\train\\train_text2sql_small.csv', 'row': 134}),
#  Document(page_content='question: What is the round when they played against Middlesbrough, and the h/a was h?\nsql: SELECT Round FROM table WHERE Opponents = middlesbrough AND H / A = h', metadata={'source': 'C:\\Users\\Rutvik\\LLM_SQL\\train\\train_text2sql_small.csv', 'row': 135}),
#  Document(page_content='question: What is every GICS sector for free float of 0.3180?\nsql: SELECT GICS Sector FROM table WHERE Free float = 0.3180', metadata={'source': 'C:\\Users\\Rutvik\\LLM_SQL\\train\\train_text2sql_small.csv', 'row': 136}),
#  Document(page_content='question: Who had the high assists when the high rebounds were from Nick Collison (15)?\nsql: SELECT High assists FROM table WHERE High rebounds = Nick Collison (15)', metadata={'source': 'C:\\Users\\Rutvik\\LLM_SQL\\train\\train_text2sql_small.csv', 'row': 137}),
#  Document(page_content='question: What is the power of the engine with a combined consumption of (gas/ethanol) and the k7m hi-torque code?\nsql: SELECT Power FROM table WHERE Combined consumption = (gas/ethanol) AND Code = k7m hi-torque', metadata={'source': 'C:\\Users\\Rutvik\\LLM_SQL\\train\\train_text2sql_small.csv', 'row': 138}),
#  Document(page_content='question: What is the time/retired for grid 23?\nsql: SELECT Time/Retired FROM table WHERE Grid = 23', metadata={'source': 'C:\\Users\\Rutvik\\LLM_SQL\\train\\train_text2sql_small.csv', 'row': 139}),
#  Document(page_content="question: What's the highest lane of rank 4 with a time less than 24.72?\nsql: SELECT MAX Lane FROM table WHERE Time < 24.72 AND Rank = 4", metadata={'source': 'C:\\Users\\Rutvik\\LLM_SQL\\train\\train_text2sql_small.csv', 'row': 140}),
#  Document(page_content='question: What is the latest Year with Marianne Jean-Baptiste as the Golden Globe Actor?\nsql: SELECT MAX Year FROM table WHERE Actor = marianne jean-baptiste', metadata={'source': 'C:\\Users\\Rutvik\\LLM_SQL\\train\\train_text2sql_small.csv', 'row': 141}),
#  Document(page_content='question: What station has a genre of talk music and is in Malay English language?\nsql: SELECT Station FROM table WHERE Genre = talk music AND Language = malay english', metadata={'source': 'C:\\Users\\Rutvik\\LLM_SQL\\train\\train_text2sql_small.csv', 'row': 142}),
#  Document(page_content='question: What location had 1:59:12 in time?\nsql: SELECT Location FROM table WHERE Time = 1:59:12', metadata={'source': 'C:\\Users\\Rutvik\\LLM_SQL\\train\\train_text2sql_small.csv', 'row': 143}),
#  Document(page_content='question: Who was the outgoing manager when the incoming manager was augusto inácio?\nsql: SELECT Outgoing manage FROM table WHERE Incoming manager = augusto inácio', metadata={'source': 'C:\\Users\\Rutvik\\LLM_SQL\\train\\train_text2sql_small.csv', 'row': 144}),
#  Document(page_content='question: Can you tell me the highest Played that has the Points larger than 11, and the Lost larger than 7?\nsql: SELECT MAX Played FROM table WHERE Points > 11 AND Lost > 7', metadata={'source': 'C:\\Users\\Rutvik\\LLM_SQL\\train\\train_text2sql_small.csv', 'row': 145}),
#  Document(page_content='question: What is the original air date of the episode with a production code of 105?\nsql: SELECT Original air date FROM table WHERE Prod. code = 105', metadata={'source': 'C:\\Users\\Rutvik\\LLM_SQL\\train\\train_text2sql_small.csv', 'row': 146}),
#  Document(page_content='question: How many total innings have an average under 6.33, strike rate under 71.43, balls faced over 36, and smaller than 19 runs scored?\nsql: SELECT SUM Innings FROM table WHERE Average < 6.33 AND S.R. < 71.43 AND Balls Faced > 36 AND Runs Scored < 19', metadata={'source': 'C:\\Users\\Rutvik\\LLM_SQL\\train\\train_text2sql_small.csv', 'row': 147}),
#  Document(page_content='question: What position has 1958 as the NFL Draft, and jerry kramer as the player?\nsql: SELECT Position FROM table WHERE NFL Draft = 1958 AND Player = jerry kramer', metadata={'source': 'C:\\Users\\Rutvik\\LLM_SQL\\train\\train_text2sql_small.csv', 'row': 148}),
#  Document(page_content='question: Name the high points for 21-45 record\nsql: SELECT COUNT High Points FROM table WHERE Record = 21-45', metadata={'source': 'C:\\Users\\Rutvik\\LLM_SQL\\train\\train_text2sql_small.csv', 'row': 149}),
#  Document(page_content='question: Who is the arranger for Ana Rouh?\nsql: SELECT Arranger FROM table WHERE Title = ana rouh', metadata={'source': 'C:\\Users\\Rutvik\\LLM_SQL\\train\\train_text2sql_small.csv', 'row': 150}),
#  Document(page_content='question: What is the regular season 1 result of the season when the Copa México was no longer played, the pyramid level was 2, and the regular season 2 result was 15th?\nsql: SELECT Regular Season 1 FROM table WHERE Copa México = no longer played AND Pyramid Level = 2 AND Regular Season 2 = 15th', metadata={'source': 'C:\\Users\\Rutvik\\LLM_SQL\\train\\train_text2sql_small.csv', 'row': 151}),
#  Document(page_content='question: Who is the Incumbent with Results of 68% 32%?\nsql: SELECT Incumbent FROM table WHERE Results = 68% 32%', metadata={'source': 'C:\\Users\\Rutvik\\LLM_SQL\\train\\train_text2sql_small.csv', 'row': 152}),
#  Document(page_content="question: what's the\xa0evening gown\xa0with\xa0swimsuit\xa0being 9.134\nsql: SELECT Evening Gown FROM table WHERE Swimsuit = 9.134", metadata={'source': 'C:\\Users\\Rutvik\\LLM_SQL\\train\\train_text2sql_small.csv', 'row': 153}),
#  Document(page_content="question: What's the average year with a rank less than 3?\nsql: SELECT AVG Year FROM table WHERE Rank < 3", metadata={'source': 'C:\\Users\\Rutvik\\LLM_SQL\\train\\train_text2sql_small.csv', 'row': 154}),
#  Document(page_content='question: Who was the turbine manufacturer for the Wheatland county?\nsql: SELECT Turbine Manufacturer FROM table WHERE County = Wheatland', metadata={'source': 'C:\\Users\\Rutvik\\LLM_SQL\\train\\train_text2sql_small.csv', 'row': 155}),
#  Document(page_content='question: What is the series number of the episode "Fly"?\nsql: SELECT COUNT No. in series FROM table WHERE Title = "Fly"', metadata={'source': 'C:\\Users\\Rutvik\\LLM_SQL\\train\\train_text2sql_small.csv', 'row': 156}),
#  Document(page_content='question: Name the Series  with Production Number of 95, br 1254?\nsql: SELECT Series FROM table WHERE Production Number = 95, br 1254', metadata={'source': 'C:\\Users\\Rutvik\\LLM_SQL\\train\\train_text2sql_small.csv', 'row': 157}),
#  Document(page_content='question: What is the year for the  genre of emo and artist is all-american rejects and song title is " move along "?\nsql: SELECT MAX Year FROM table WHERE Genre = Emo AND Artist = All-American Rejects AND Song title = " Move Along "', metadata={'source': 'C:\\Users\\Rutvik\\LLM_SQL\\train\\train_text2sql_small.csv', 'row': 158}),
#  Document(page_content='question: Name the region for cd format on february 22, 1984\nsql: SELECT Region FROM table WHERE Format = cd AND Date = february 22, 1984', metadata={'source': 'C:\\Users\\Rutvik\\LLM_SQL\\train\\train_text2sql_small.csv', 'row': 159}),
#  Document(page_content='question: Which first round has a first team of angers sco (d1)?\nsql: SELECT 1st round FROM table WHERE Team 1 = angers sco (d1)', metadata={'source': 'C:\\Users\\Rutvik\\LLM_SQL\\train\\train_text2sql_small.csv', 'row': 160}),
#  Document(page_content='question: In what round did Mike Newton Thomas Erdos Ben Collins won the LMP2?\nsql: SELECT Rnd. FROM table WHERE LMP2 Winning Team = Mike Newton Thomas Erdos Ben Collins', metadata={'source': 'C:\\Users\\Rutvik\\LLM_SQL\\train\\train_text2sql_small.csv', 'row': 161}),
#  Document(page_content='question: What is the long for the player with 26 carries?\nsql: SELECT Long FROM table WHERE Car. = 26', metadata={'source': 'C:\\Users\\Rutvik\\LLM_SQL\\train\\train_text2sql_small.csv', 'row': 162}),
#  Document(page_content='question: What LNER Class has a Class of 6db?\nsql: SELECT LNER Class FROM table WHERE Class = 6db', metadata={'source': 'C:\\Users\\Rutvik\\LLM_SQL\\train\\train_text2sql_small.csv', 'row': 163}),
#  Document(page_content='question: Which team won at the symmons plains raceway?\nsql: SELECT Team FROM table WHERE Circuit = symmons plains raceway', metadata={'source': 'C:\\Users\\Rutvik\\LLM_SQL\\train\\train_text2sql_small.csv', 'row': 164}),
#  Document(page_content='question: What time/retired has a Grid larger than 3, and a Driver of kimi räikkönen?\nsql: SELECT Time/Retired FROM table WHERE Grid > 3 AND Driver = kimi räikkönen', metadata={'source': 'C:\\Users\\Rutvik\\LLM_SQL\\train\\train_text2sql_small.csv', 'row': 165}),
#  Document(page_content='question: What time period had appearances of 219?\nsql: SELECT Period FROM table WHERE Appearances¹ = 219', metadata={'source': 'C:\\Users\\Rutvik\\LLM_SQL\\train\\train_text2sql_small.csv', 'row': 166}),
#  Document(page_content='question: What is the last season the Worcester Wolves played?\nsql: SELECT Last season FROM table WHERE Team = worcester wolves', metadata={'source': 'C:\\Users\\Rutvik\\LLM_SQL\\train\\train_text2sql_small.csv', 'row': 167}),
#  Document(page_content='question: What average week number had the Chicago bears as the opponent?\nsql: SELECT AVG Week FROM table WHERE Opponent = chicago bears', metadata={'source': 'C:\\Users\\Rutvik\\LLM_SQL\\train\\train_text2sql_small.csv', 'row': 168}),
#  Document(page_content='question: What is the result of the match with Zab Judah as the opponent?\nsql: SELECT Result FROM table WHERE Opponent = zab judah', metadata={'source': 'C:\\Users\\Rutvik\\LLM_SQL\\train\\train_text2sql_small.csv', 'row': 169}),
#  Document(page_content='question: Which Water (sqmi) has a Township of yorktown, and a GEO ID smaller than 3802187940?\nsql: SELECT MIN Water (sqmi) FROM table WHERE Township = yorktown AND GEO ID < 3802187940', metadata={'source': 'C:\\Users\\Rutvik\\LLM_SQL\\train\\train_text2sql_small.csv', 'row': 170}),
#  Document(page_content='question: Who was the winner when the third place was fernando meligeni?\nsql: SELECT Winner FROM table WHERE Third Place = fernando meligeni', metadata={'source': 'C:\\Users\\Rutvik\\LLM_SQL\\train\\train_text2sql_small.csv', 'row': 171}),
#  Document(page_content='question: What show that was aired on January 24, 2008 with a rating larger than 3.6 had the lowest viewers? How Many Viewers in the millions?\nsql: SELECT MIN Viewers (m) FROM table WHERE Air Date = january 24, 2008 AND Rating > 3.6', metadata={'source': 'C:\\Users\\Rutvik\\LLM_SQL\\train\\train_text2sql_small.csv', 'row': 172}),
#  Document(page_content='question: What was the away team score when the home team essendon was playing?\nsql: SELECT Away team score FROM table WHERE Home team = essendon', metadata={'source': 'C:\\Users\\Rutvik\\LLM_SQL\\train\\train_text2sql_small.csv', 'row': 173}),
#  Document(page_content='question: Name the record for score of w 76-67\nsql: SELECT Record FROM table WHERE Score = W 76-67', metadata={'source': 'C:\\Users\\Rutvik\\LLM_SQL\\train\\train_text2sql_small.csv', 'row': 174}),
#  Document(page_content='question: Which episode was written by anthony e. zuiker & ken solarz\nsql: SELECT Title FROM table WHERE Written by = Anthony E. Zuiker & Ken Solarz', metadata={'source': 'C:\\Users\\Rutvik\\LLM_SQL\\train\\train_text2sql_small.csv', 'row': 175}),
#  Document(page_content='question: How old were Mitchell & Jessica when they danced the Cha-Cha-Cha?\nsql: SELECT Ages FROM table WHERE Dance = cha-cha-cha AND Pair = mitchell & jessica', metadata={'source': 'C:\\Users\\Rutvik\\LLM_SQL\\train\\train_text2sql_small.csv', 'row': 176}),
#  Document(page_content='question: What is the fewest mintage from Dora de Pédery-Hunt, and the year was before 2002?\nsql: SELECT MIN Mintage FROM table WHERE Artist = dora de pédery-hunt AND Year < 2002', metadata={'source': 'C:\\Users\\Rutvik\\LLM_SQL\\train\\train_text2sql_small.csv', 'row': 177}),
#  Document(page_content='question: Which Against has a Draws larger than 0, a Losses smaller than 16, and a Wins smaller than 4?\nsql: SELECT MAX Against FROM table WHERE Draws > 0 AND Losses < 16 AND Wins < 4', metadata={'source': 'C:\\Users\\Rutvik\\LLM_SQL\\train\\train_text2sql_small.csv', 'row': 178}),
#  Document(page_content='question: What was the 1st leg for a team 1 of Teteks?\nsql: SELECT 1st leg FROM table WHERE Team 1 = teteks', metadata={'source': 'C:\\Users\\Rutvik\\LLM_SQL\\train\\train_text2sql_small.csv', 'row': 179}),
# ...
#  Document(page_content='question: I want the total number of Laps for Rubens Barrichello\nsql: SELECT COUNT Laps FROM table WHERE Driver = rubens barrichello', metadata={'source': 'C:\\Users\\Rutvik\\LLM_SQL\\train\\train_text2sql_small.csv', 'row': 504}),
#  Document(page_content='question: How many rounds have a Pick smaller than 10, and a Name of larry hendershot?\nsql: SELECT COUNT Round FROM table WHERE Pick < 10 AND Name = larry hendershot', metadata={'source': 'C:\\Users\\Rutvik\\LLM_SQL\\train\\train_text2sql_small.csv', 'row': 505}),
#  Document(page_content='question: What date did Namigata play against Wen-Hsin Hsu in the finals?\nsql: SELECT Date FROM table WHERE Opponent in the final = wen-hsin hsu', metadata={'source': 'C:\\Users\\Rutvik\\LLM_SQL\\train\\train_text2sql_small.csv', 'row': 506}),
#  Document(page_content='question: What is the population for the region with an area of 6,004 sq. Mi.?\nsql: SELECT Population FROM table WHERE Area (sq. mi.) = 6,004', metadata={'source': 'C:\\Users\\Rutvik\\LLM_SQL\\train\\train_text2sql_small.csv', 'row': 507}),
#  Document(page_content='question: What is the average grid for johnny dumfries with less than 8 laps?\nsql: SELECT AVG Grid FROM table WHERE Driver = johnny dumfries AND Laps < 8', metadata={'source': 'C:\\Users\\Rutvik\\LLM_SQL\\train\\train_text2sql_small.csv', 'row': 508}),
#  Document(page_content='question: Name the score for game 5\nsql: SELECT Score FROM table WHERE Game = 5', metadata={'source': 'C:\\Users\\Rutvik\\LLM_SQL\\train\\train_text2sql_small.csv', 'row': 509}),
#  Document(page_content='question: Who was played against with a result of 3–6, 2–6?\nsql: SELECT Against FROM table WHERE Result = 3–6, 2–6', metadata={'source': 'C:\\Users\\Rutvik\\LLM_SQL\\train\\train_text2sql_small.csv', 'row': 510}),
#  Document(page_content='question: how many\xa0airport\xa0with\xa0rank\xa0being 4\nsql: SELECT COUNT Airport FROM table WHERE Rank = 4', metadata={'source': 'C:\\Users\\Rutvik\\LLM_SQL\\train\\train_text2sql_small.csv', 'row': 511}),
#  Document(page_content='question: Name the games for rubén limardo\nsql: SELECT Games FROM table WHERE Name = rubén limardo', metadata={'source': 'C:\\Users\\Rutvik\\LLM_SQL\\train\\train_text2sql_small.csv', 'row': 512}),
#  Document(page_content="question: Who was the girl on week 5 that came after week 3's Shelly Louise?\nsql: SELECT Week 5 FROM table WHERE Week 3 = shelly louise", metadata={'source': 'C:\\Users\\Rutvik\\LLM_SQL\\train\\train_text2sql_small.csv', 'row': 513}),
#  Document(page_content='question: What are the earpads for the headphones that are Reference class and have MSRP of $695?\nsql: SELECT Earpads FROM table WHERE Headphone Class = reference AND US MSRP = $695', metadata={'source': 'C:\\Users\\Rutvik\\LLM_SQL\\train\\train_text2sql_small.csv', 'row': 514}),
#  Document(page_content='question: What is the country is ranked more than 4?\nsql: SELECT Country FROM table WHERE Rank > 4', metadata={'source': 'C:\\Users\\Rutvik\\LLM_SQL\\train\\train_text2sql_small.csv', 'row': 515}),
#  Document(page_content='question: When was the episode titled "The Boost Job" originally aired?\nsql: SELECT Original air date FROM table WHERE Title = "The Boost Job"', metadata={'source': 'C:\\Users\\Rutvik\\LLM_SQL\\train\\train_text2sql_small.csv', 'row': 516}),
#  Document(page_content='question: What was the surface for the game that was played on 12-Apr-2005?\nsql: SELECT Surface FROM table WHERE Date = 12-apr-2005', metadata={'source': 'C:\\Users\\Rutvik\\LLM_SQL\\train\\train_text2sql_small.csv', 'row': 517}),
#  Document(page_content='question: What is the lowest pick number where the overall pick number was 38?\nsql: SELECT MIN Pick FROM table WHERE Overall = 38', metadata={'source': 'C:\\Users\\Rutvik\\LLM_SQL\\train\\train_text2sql_small.csv', 'row': 518}),
#  Document(page_content="question: Who are all the players who've bowled more than 4969 balls?\nsql: SELECT Name FROM table WHERE Balls bowled = 4969", metadata={'source': 'C:\\Users\\Rutvik\\LLM_SQL\\train\\train_text2sql_small.csv', 'row': 519}),
#  Document(page_content='question: What category was Scream nominated for at the International Horror Guild?\nsql: SELECT Category FROM table WHERE Work = scream AND Award = international horror guild', metadata={'source': 'C:\\Users\\Rutvik\\LLM_SQL\\train\\train_text2sql_small.csv', 'row': 520}),
#  Document(page_content='question: When are all dates with a score of 205 (–8)  in Australia?\nsql: SELECT Dates FROM table WHERE Score = 205 (–8) AND Country = Australia', metadata={'source': 'C:\\Users\\Rutvik\\LLM_SQL\\train\\train_text2sql_small.csv', 'row': 521}),
#  Document(page_content='question: What is the greatest Total, when the FA Cup is 0, when the Name is Robbie Williams Category:Articles with hCards, and when the League Cup is less than 0?\nsql: SELECT MAX Total FROM table WHERE FA Cup = 0 AND Name = robbie williams category:articles with hcards AND League Cup < 0', metadata={'source': 'C:\\Users\\Rutvik\\LLM_SQL\\train\\train_text2sql_small.csv', 'row': 522}),
#  Document(page_content='question: Which competition with a result of 3-1?\nsql: SELECT Competition FROM table WHERE Result = 3-1', metadata={'source': 'C:\\Users\\Rutvik\\LLM_SQL\\train\\train_text2sql_small.csv', 'row': 523}),
#  Document(page_content='question: In which season did Jimmy Eriksson win the championship for Team Lotus?\nsql: SELECT Season FROM table WHERE Team = lotus AND Champion = jimmy eriksson', metadata={'source': 'C:\\Users\\Rutvik\\LLM_SQL\\train\\train_text2sql_small.csv', 'row': 524}),
#  Document(page_content='question: Who had the highest rebounds of the game on April 7?\nsql: SELECT High rebounds FROM table WHERE Date = april 7', metadata={'source': 'C:\\Users\\Rutvik\\LLM_SQL\\train\\train_text2sql_small.csv', 'row': 525}),
#  Document(page_content='question: What was the lowest attendance recorded at a game on September 28?\nsql: SELECT MIN Attendance FROM table WHERE Date = september 28', metadata={'source': 'C:\\Users\\Rutvik\\LLM_SQL\\train\\train_text2sql_small.csv', 'row': 526}),
#  Document(page_content='question: Which website was started in 2008?\nsql: SELECT Website FROM table WHERE Year started = 2008', metadata={'source': 'C:\\Users\\Rutvik\\LLM_SQL\\train\\train_text2sql_small.csv', 'row': 527}),
#  Document(page_content='question: What is the highest grid that tetsuya harada rode in?\nsql: SELECT MAX Grid FROM table WHERE Rider = tetsuya harada', metadata={'source': 'C:\\Users\\Rutvik\\LLM_SQL\\train\\train_text2sql_small.csv', 'row': 528}),
#  Document(page_content='question: What is the Week on November 10, 1996?\nsql: SELECT Week FROM table WHERE Date = november 10, 1996', metadata={'source': 'C:\\Users\\Rutvik\\LLM_SQL\\train\\train_text2sql_small.csv', 'row': 529}),
#  Document(page_content="question: What is the name of the candidate from happy valley-goose bay with a gender of m?\nsql: SELECT Candidate's Name FROM table WHERE Gender = m AND Residence = happy valley-goose bay", metadata={'source': 'C:\\Users\\Rutvik\\LLM_SQL\\train\\train_text2sql_small.csv', 'row': 530}),
#  Document(page_content='question: When revenue is smaller than 4,177 million in year 2008, what is the sum of earnings per share?\nsql: SELECT SUM Earnings per share (p) FROM table WHERE Year ended = 2008 AND Revenue (£million) < 4,177', metadata={'source': 'C:\\Users\\Rutvik\\LLM_SQL\\train\\train_text2sql_small.csv', 'row': 531}),
#  Document(page_content='question: What Name has a Time of 01:56:52?\nsql: SELECT Name FROM table WHERE Time = 01:56:52', metadata={'source': 'C:\\Users\\Rutvik\\LLM_SQL\\train\\train_text2sql_small.csv', 'row': 532}),
#  Document(page_content='question: What is the length for years 2012-2013?\nsql: SELECT Length FROM table WHERE Year = 2012-2013', metadata={'source': 'C:\\Users\\Rutvik\\LLM_SQL\\train\\train_text2sql_small.csv', 'row': 533}),
#  Document(page_content='question: Game of Thrones was done by which artist?\nsql: SELECT Artist FROM table WHERE Actual Title = game of thrones', metadata={'source': 'C:\\Users\\Rutvik\\LLM_SQL\\train\\train_text2sql_small.csv', 'row': 534}),
#  Document(page_content='question: WHAT IS THE ERUPE WITH HEAD COACH vainauskas , sakalauskas AND WITH NEBL FINALIST?\nsql: SELECT Europe FROM table WHERE Head Coach = vainauskas , sakalauskas AND Regional Competitions = nebl finalist', metadata={'source': 'C:\\Users\\Rutvik\\LLM_SQL\\train\\train_text2sql_small.csv', 'row': 535}),
#  Document(page_content='question: For home of River Plate, what is the first leg listed?\nsql: SELECT 1st Leg FROM table WHERE Home (2nd leg) = River Plate', metadata={'source': 'C:\\Users\\Rutvik\\LLM_SQL\\train\\train_text2sql_small.csv', 'row': 536}),
#  Document(page_content='question: Who was the home team that had a score of 13.14 (92)?\nsql: SELECT Home team FROM table WHERE Home team score = 13.14 (92)', metadata={'source': 'C:\\Users\\Rutvik\\LLM_SQL\\train\\train_text2sql_small.csv', 'row': 537}),
#  Document(page_content='question: What is the second party where the first party is Tory and the year is 1820?\nsql: SELECT Second party FROM table WHERE First party = tory AND Year = 1820', metadata={'source': 'C:\\Users\\Rutvik\\LLM_SQL\\train\\train_text2sql_small.csv', 'row': 538}),
#  Document(page_content='question: Who had the high rebounds when the score was w 105–95 (ot) and Jason Kidd (8) had the high assists?\nsql: SELECT High rebounds FROM table WHERE High assists = jason kidd (8) AND Score = w 105–95 (ot)', metadata={'source': 'C:\\Users\\Rutvik\\LLM_SQL\\train\\train_text2sql_small.csv', 'row': 539}),
#  Document(page_content='question: What is the score for Ky Laffoon?\nsql: SELECT Score FROM table WHERE Player = ky laffoon', metadata={'source': 'C:\\Users\\Rutvik\\LLM_SQL\\train\\train_text2sql_small.csv', 'row': 540}),
#  Document(page_content='question: What is the score for the away team of Grimsby Town?\nsql: SELECT Score FROM table WHERE Away team = grimsby town', metadata={'source': 'C:\\Users\\Rutvik\\LLM_SQL\\train\\train_text2sql_small.csv', 'row': 541}),
#  Document(page_content='question: What type is the sorrento to sapri course with a distance of km (mi)?\nsql: SELECT Type FROM table WHERE Distance = km (mi) AND Course = sorrento to sapri', metadata={'source': 'C:\\Users\\Rutvik\\LLM_SQL\\train\\train_text2sql_small.csv', 'row': 542}),
#  Document(page_content='question: What is the highest number of neutral losses of the Florida State Seminoles, which has less than 5 away losses?\nsql: SELECT MAX Neutral Losses FROM table WHERE Institution = florida state seminoles AND Away Losses < 5', metadata={'source': 'C:\\Users\\Rutvik\\LLM_SQL\\train\\train_text2sql_small.csv', 'row': 543}),
#  Document(page_content='question: What is the name of the airport located in Russia with an IATA of AER?\nsql: SELECT Airport FROM table WHERE Country = russia AND IATA = aer', metadata={'source': 'C:\\Users\\Rutvik\\LLM_SQL\\train\\train_text2sql_small.csv', 'row': 544}),
#  Document(page_content='question: What is average frequency MHZ when is in portales, new mexico?\nsql: SELECT AVG Frequency MHz FROM table WHERE City of license = portales, new mexico', metadata={'source': 'C:\\Users\\Rutvik\\LLM_SQL\\train\\train_text2sql_small.csv', 'row': 545}),
#  Document(page_content='question: Name the home when the visitor was dallas on february 2\nsql: SELECT Home FROM table WHERE Visitor = dallas AND Date = february 2', metadata={'source': 'C:\\Users\\Rutvik\\LLM_SQL\\train\\train_text2sql_small.csv', 'row': 546}),
#  Document(page_content='question: What is the maximum points received when Peeter Vähl gave a 9?\nsql: SELECT MIN Points FROM table WHERE Peeter Vähi = 9', metadata={'source': 'C:\\Users\\Rutvik\\LLM_SQL\\train\\train_text2sql_small.csv', 'row': 547}),
#  Document(page_content='question: What is the name of the airport with an IATA of KUF?\nsql: SELECT Airport FROM table WHERE IATA = kuf', metadata={'source': 'C:\\Users\\Rutvik\\LLM_SQL\\train\\train_text2sql_small.csv', 'row': 548}),
#  Document(page_content='question: What is the name of the director of the episode written by robin schwartz & robert tarlow?\nsql: SELECT Directed by FROM table WHERE Written by = robin schwartz & robert tarlow', metadata={'source': 'C:\\Users\\Rutvik\\LLM_SQL\\train\\train_text2sql_small.csv', 'row': 549}),
#  Document(page_content='question: What is the rank for bob murphy with under 4 wins?\nsql: SELECT COUNT Rank FROM table WHERE Player = bob murphy AND Wins < 4', metadata={'source': 'C:\\Users\\Rutvik\\LLM_SQL\\train\\train_text2sql_small.csv', 'row': 550}),
#  Document(page_content='question: What was the average size of the crowd for games where the home team had a score of 10.10 (70)?\nsql: SELECT AVG Crowd FROM table WHERE Home team score = 10.10 (70)', metadata={'source': 'C:\\Users\\Rutvik\\LLM_SQL\\train\\train_text2sql_small.csv', 'row': 551}),
#  Document(page_content='question: What is the general classification with riccardo riccò as the young rider classification?\nsql: SELECT General classification FROM table WHERE Young rider classification = riccardo riccò', metadata={'source': 'C:\\Users\\Rutvik\\LLM_SQL\\train\\train_text2sql_small.csv', 'row': 552}),
#  Document(page_content='question: Who were the directors of the episode "nano nits" written by nathan cockerill?\nsql: SELECT Director FROM table WHERE Writer = Nathan Cockerill AND Title = "Nano Nits"', metadata={'source': 'C:\\Users\\Rutvik\\LLM_SQL\\train\\train_text2sql_small.csv', 'row': 553}),
#  Document(page_content='question: What grid for denny hulme?\nsql: SELECT Grid FROM table WHERE Driver = denny hulme', metadata={'source': 'C:\\Users\\Rutvik\\LLM_SQL\\train\\train_text2sql_small.csv', 'row': 554}),
#  Document(page_content="question: What's the fewest number of pages for the title al-jiniral fi matahatihi?\nsql: SELECT MIN Pages FROM table WHERE Title = al-jiniral fi matahatihi", metadata={'source': 'C:\\Users\\Rutvik\\LLM_SQL\\train\\train_text2sql_small.csv', 'row': 555}),
#  Document(page_content='question: In what Round was Grant Long Drafted?\nsql: SELECT MIN Round FROM table WHERE Player = grant long', metadata={'source': 'C:\\Users\\Rutvik\\LLM_SQL\\train\\train_text2sql_small.csv', 'row': 556}),
#  Document(page_content='question: What is ICAO, when Airport is "Sibulan Airport"?\nsql: SELECT ICAO FROM table WHERE Airport = sibulan airport', metadata={'source': 'C:\\Users\\Rutvik\\LLM_SQL\\train\\train_text2sql_small.csv', 'row': 557}),
#  Document(page_content='question: When 7.08 is the amount of viewers what is the air date?\nsql: SELECT Air date FROM table WHERE Viewers = 7.08', metadata={'source': 'C:\\Users\\Rutvik\\LLM_SQL\\train\\train_text2sql_small.csv', 'row': 558}),
#  Document(page_content='question: What was the highest number of wins for any team?\nsql: SELECT MAX Wins FROM table', metadata={'source': 'C:\\Users\\Rutvik\\LLM_SQL\\train\\train_text2sql_small.csv', 'row': 559}),
#  Document(page_content='question: How many silvers on average for nations with less than 3 total, ranked 6, and over 1 bronze?\nsql: SELECT AVG Silver FROM table WHERE Total < 3 AND Rank = 6 AND Bronze > 1', metadata={'source': 'C:\\Users\\Rutvik\\LLM_SQL\\train\\train_text2sql_small.csv', 'row': 560}),
#  Document(page_content='question: What was the Competition on September 29, 2003?\nsql: SELECT Competition FROM table WHERE Date = september 29, 2003', metadata={'source': 'C:\\Users\\Rutvik\\LLM_SQL\\train\\train_text2sql_small.csv', 'row': 561}),
#  Document(page_content='question: Which Result has a Round larger than 17?\nsql: SELECT Result FROM table WHERE Round > 17', metadata={'source': 'C:\\Users\\Rutvik\\LLM_SQL\\train\\train_text2sql_small.csv', 'row': 562}),
#  Document(page_content='question: Who had the high assists when the score was w 107–95 (ot)?\nsql: SELECT High assists FROM table WHERE Score = W 107–95 (OT)', metadata={'source': 'C:\\Users\\Rutvik\\LLM_SQL\\train\\train_text2sql_small.csv', 'row': 563})]

# %% [markdown]
# #### Vector Database:

# %%
from sentence_transformers import SentenceTransformer
model = SentenceTransformer('all-MiniLM-L6-v2')

#Our sentences we like to encode
sentences = ['This framework generates embeddings for each input sentence',
    'Sentences are passed as a list of string.',
    'The quick brown fox jumps over the lazy dog.']

#Sentences are encoded by calling model.encode()
embeddings = model.encode(sentences)

#Print the embeddings
for sentence, embedding in zip(sentences, embeddings):
    print("Sentence:", sentence)
    print("Embedding:", embedding)
    print("")
# Out:
# Sentence: This framework generates embeddings for each input sentence
# Embedding: [-1.37173375e-02 -4.28515524e-02 -1.56286061e-02  1.40537517e-02
#   3.95537987e-02  1.21796295e-01  2.94333640e-02 -3.17523815e-02
#   3.54959480e-02 -7.93140158e-02  1.75878331e-02 -4.04369719e-02
#   4.97259796e-02  2.54912823e-02 -7.18700588e-02  8.14968571e-02
#   1.47074426e-03  4.79627438e-02 -4.50336039e-02 -9.92174968e-02
#  -2.81769708e-02  6.45046085e-02  4.44670543e-02 -4.76217009e-02
#  -3.52952927e-02  4.38671596e-02 -5.28566539e-02  4.32992238e-04
#   1.01921462e-01  1.64072327e-02  3.26996557e-02 -3.45986672e-02
#  -4.45531011e-02 -2.89850123e-02 -8.96776393e-02 -1.75943761e-03
#  -2.61486191e-02  5.93999773e-03 -5.18355332e-02  8.57279524e-02
#  -8.18398967e-02  8.35442636e-03  4.00790460e-02  4.17764112e-02
#   1.04573533e-01 -2.86558107e-03  1.96690951e-02  5.81049593e-03
#   1.33253327e-02  4.51000929e-02 -2.17588395e-02 -1.39493067e-02
#  -6.86992630e-02 -2.94113974e-03 -3.10765281e-02 -1.05854400e-01
#   6.91624135e-02 -4.24114689e-02 -4.67682593e-02 -3.64750922e-02
#   4.50399853e-02  6.09817058e-02 -6.56561479e-02 -5.45639778e-03
#  -1.86226945e-02 -6.31484389e-02 -3.87436785e-02  3.46733741e-02
#   5.55458516e-02  5.21627739e-02  5.61065264e-02  1.02063909e-01]

# %%
# Split text into chunks of 512 tokens, with 20% token overlap:
text_splitter = TokenTextSplitter(chunk_size=512, chunk_overlap=103)

def num_tokens_from_string(string: str, encoding_name="cl100k_base") -> int:
    """Calculate number of tokens in a text string."""
    if not string:
        return 0
    
    # Returns the number of tokens in a text string
    encoding = tiktoken.get_encoding(encoding_name)
    num_tokens = len(encoding.encode(string))
    
    return num_tokens

# %%
# List for smaller chunked text and metadata:
new_list = []

# Create a new list by splitting up text into token sizes of around 512 tokens:
for i in range(len(input_data.index)):
    text = input_data['question'][i]
    token_len = num_tokens_from_string(text)
    if token_len <= 512:
        new_list.append([input_data['question'][i], input_data['sql'][i]])
    else:
        #split text into chunks using text splitter
        split_text = text_splitter.split_text(text)
        for j in range(len(split_text)):
            new_list.append([input_data['question'][i], split_text[j], input_data['sql'][i]])

# %%
df_new = pd.DataFrame(new_list, columns=['question', 'sql'])
df_new.head()
# Out:
#                                             question  \
# 0    Tell me what the notes are for South Australia
# 1  What is the current series where the new serie...
# 2            What is the format for South Australia?
# 3  Name the background colour for the Australian ...
# 4      how many times is the fuel propulsion is cng?
#
#                                                  sql
# 0  SELECT Notes FROM table WHERE Current slogan =...
# 1  SELECT Current series FROM table WHERE Notes =...
# 2  SELECT Format FROM table WHERE State/territory...
# 3  SELECT Text/background colour FROM table WHERE...
# 4  SELECT COUNT Fleet Series (Quantity) FROM tabl...

# %%
from langchain.document_loaders import DataFrameLoader

# page_content_column is the column name in the dataframe to create embeddings for:
loader = DataFrameLoader(df_new, page_content_column = 'question')
docs = loader.load()

# %%
embeddings = HuggingFaceEmbeddings()
retrieval_db = FAISS.from_documents(docs, embeddings)

# %%
def retrieve_info(query):
    """Performs similarity search basis the input query and returns the contents as an array."""
    
    simi_search = retrieval_db.similarity_search(query, k=3)
    retrieved_info = [info.page_content for info in simi_search]    
    return retrieved_info

# %%
question = """Get the data from purchasepricesdec table where the price is greater than 100?"""

# %%
print(retrieve_info(query))

# %%
print(retrieve_info(query)[0])

# %%
template = """ 
Given a question, first create a syntactically correct MySQL query by referring to the help provided in the sample questions 
and answers, then display the results of the MySQL query.  

The following is the question from the user:
{question}

sample question and sql answers:
{sample}
"""

prompt = PromptTemplate(input_variables=["question", "sample"], template=template)

# %%
rag_db_chain = SQLDatabaseChain.from_llm(llm=llm, db=db, verbose=True)

# %%
sample_ret = retrieve_info(question)
response = rag_db_chain.run(template.format(question=question, sample=sample_ret))
response
